# %%
import tensorflow as tf
from tensorflow.keras.applications import inception_v3
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dropout,Input,Flatten,Dense,MaxPooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
tf.config.list_physical_devices('GPU')
# Out:
# []

# %%
batchsize=8

# %%
train_datagen= ImageDataGenerator(rescale=1./255, rotation_range=0.2,shear_range=0.2,zoom_range=0.2,width_shift_range=0.2,height_shift_range=0.2, validation_split=0.2)

# %%
train_data= train_datagen.flow_from_directory(r'C:\Users\HP\Desktop\Drowsiness Detection\Prepared_Data\train',target_size=(80,80),batch_size=batchsize,class_mode='categorical', subset='training')
validation_data= train_datagen.flow_from_directory(r'C:\Users\HP\Desktop\Drowsiness Detection\Prepared_Data\train',target_size=(80,80),batch_size=batchsize,class_mode='categorical', subset='validation')
# Out:
# Found 64303 images belonging to 2 classes.
# Found 16075 images belonging to 2 classes.

# %%
test_datagen = ImageDataGenerator(rescale=1./255)

test_data = test_datagen.flow_from_directory(r'C:\Users\HP\Desktop\Drowsiness Detection\Prepared_Data\test',target_size=(80,80),batch_size=batchsize,class_mode='categorical')
# Out:
# Found 4520 images belonging to 2 classes.

# %%
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.layers import Input

# Create the model
bmodel = InceptionV3(include_top=False, weights='imagenet', input_tensor=Input(shape=(80, 80, 3)))
hmodel = bmodel.output
hmodel = Flatten()(hmodel)
hmodel = Dense(64,activation='relu')(hmodel)
hmodel = Dropout(0.5)(hmodel)
hmodel = Dense(2,activation='softmax')(hmodel)

model = Model(inputs=bmodel.input, outputs= hmodel)
for layer in bmodel.layers:
    layer.trainable = False

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 80, 80, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 39, 39,    │        864 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 39, 39,    │         96 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

# Corrected file path to end with .keras
checkpoint = ModelCheckpoint(r'C:\Users\HP\Desktop\Drowsiness Detection\models\best_model.keras', monitor='val_loss', save_best_only=True, verbose=3)

# Corrected spelling of 'monitor'
earlystop = EarlyStopping(monitor='val_loss', patience=7, verbose=3, restore_best_weights=True)

# Reduce learning rate on plateau
learning_rate = ReduceLROnPlateau(monitor='val_loss', patience=3, verbose=3)

callbacks=[checkpoint,earlystop,learning_rate]

# %%
from tensorflow.keras.optimizers import Adam

# Compile the model with an instantiated Adam optimizer
model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])

# Use model.fit instead of fit_generator
model.fit(
    train_data,
    steps_per_epoch=train_data.samples // batchsize,  # Number of steps per epoch
    validation_data=validation_data,
    validation_steps=validation_data.samples // batchsize,  # Validation steps
    callbacks=callbacks,  # Assuming 'callbacks' is a list containing checkpoint, early stopping, etc.
    epochs=5
)
# Out:
# Epoch 1/5
# C:\Users\HP\AppData\Roaming\Python\Python311\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 8037/8037 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.9055 - loss: 0.2328
# Epoch 1: val_loss improved from inf to 0.18567, saving model to C:\Users\HP\Desktop\Drowsiness Detection\models\best_model.keras
# 8037/8037 ━━━━━━━━━━━━━━━━━━━━ 663s 79ms/step - accuracy: 0.9055 - loss: 0.2328 - val_accuracy: 0.9226 - val_loss: 0.1857 - learning_rate: 0.0010
# Epoch 2/5
#    1/8037 ━━━━━━━━━━━━━━━━━━━━ 6:01 45ms/step - accuracy: 1.0000 - loss: 0.1439
# ...

# %%
# Evaluate the model using the generator
acc_tr, loss_tr = model.evaluate(train_data)

print(f"Accuracy: {acc_tr}")
print(f"Loss: {loss_tr}")
# Out:
# 8038/8038 ━━━━━━━━━━━━━━━━━━━━ 317s 39ms/step - accuracy: 0.9405 - loss: 0.1566
# Accuracy: 0.16111905872821808
# Loss: 0.9387120604515076

# %%
# Evaluate the model using the validation data generator
acc_vr, loss_vr = model.evaluate(validation_data)

print(f"Validation Accuracy: {acc_vr}")
print(f"Validation Loss: {loss_vr}")
# Out:
# 2010/2010 ━━━━━━━━━━━━━━━━━━━━ 79s 39ms/step - accuracy: 0.9195 - loss: 0.2008
# Validation Accuracy: 0.19750504195690155
# Validation Loss: 0.9211819767951965

# %%
# Evaluate the model using the test data generator
acc_test, loss_test = model.evaluate(test_data)

print(f"Test Accuracy: {acc_test}")
print(f"Test Loss: {loss_test}")
# Out:
# 565/565 ━━━━━━━━━━━━━━━━━━━━ 45s 79ms/step - accuracy: 0.8064 - loss: 0.6756
# Test Accuracy: 0.6775439381599426
# Test Loss: 0.8048672676086426
